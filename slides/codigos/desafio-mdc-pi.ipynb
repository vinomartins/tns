# %%
import time
from IPython.display import display, clear_output

rep = 500
e = 3
k = 10^e

coprimos = 0
erros = []

for i in [1..rep]:
  (a,b) = (randint(1,k),randint(1,k))
  if gcd(a,b) == 1:
    coprimos += 1
  prop = coprimos/i
  if prop != 0:
    erro = n(sqrt(6/prop))  
    erros.append((i,erro))
    P1 = list_plot(erros)
    P2 = plot(pi,0,i,color='red')
    T1 = text(str(erro)+' ' +str(prop),(i/2,4))
    show(P1+P2+T1)
    clear_output(wait=True)
    time.sleep(0.1)
# Out:
# Graphics object consisting of 3 graphics primitives
